# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import tensorflow as tf

# %%
# Check for GPU
import tensorflow as tf
try:
    from google.colab import drive
    IN_COLAB=True
except:
    IN_COLAB=False

if IN_COLAB:
    print("We're running Colab")
else:
    print(tf.config.list_physical_devices())
    print('\nCUDA GPU: ' + str(tf.test.is_gpu_available(cuda_only=True)))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING:tensorflow:From C:\Users\Beebe\AppData\Local\Temp\ipykernel_20272\4004085722.py:13: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
#
# CUDA GPU: True

# %%
df = pd.read_csv('./daily01-ithaca/daily01-NY_Ithaca_13_E.csv', header = 0, index_col = 0)

# %%
df
# Out:
#      WBANNO  LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0     64758  20041027   1.201     -76.25     42.44          NaN          NaN
# 1     64758  20041028   1.201     -76.25     42.44         12.7         -0.3
# 2     64758  20041029   1.201     -76.25     42.44         16.3          2.5
# 3     64758  20041030   1.201     -76.25     42.44         17.5         10.5
# 4     64758  20041031   1.201     -76.25     42.44         17.0          9.1
# ..      ...       ...     ...        ...       ...          ...          ...
# 304   64758  20231101   2.622     -76.25     42.44          3.5         -2.2
# 305   64758  20231102   2.622     -76.25     42.44          6.1         -3.3
# 306   64758  20231103   2.622     -76.25     42.44         12.9          1.4
# 307   64758  20231104   2.622     -76.25     42.44         13.4          5.7
# 308   64758  20231105   2.622     -76.25     42.44          NaN          NaN
#
#      T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  ...  SOIL_MOISTURE_5_DAILY  \
# 0             NaN          NaN           NaN  ...                    NaN
# 1             6.2          5.0           0.0  ...                    NaN
# 2             9.4          9.7           0.0  ...                    NaN
# 3            14.0         14.5           1.8  ...                    NaN
# 4            13.1         12.6           0.0  ...                    NaN
# ..            ...          ...           ...  ...                    ...
# 304           0.6          0.2           3.0  ...                  0.352
# 305           1.4          1.0           0.0  ...                  0.352
# 306           7.1          7.4           0.0  ...                  0.345
# 307           9.6          9.5           0.0  ...                  0.338
# 308           NaN          NaN           NaN  ...                    NaN
#
#     SOIL_MOISTURE_10_DAILY  SOIL_MOISTURE_20_DAILY  SOIL_MOISTURE_50_DAILY  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
# ..                     ...                     ...                     ...
# 304                  0.328                   0.329                   0.364
# 305                  0.323                   0.325                   0.357
# 306                  0.319                   0.320                   0.327
# 307                  0.313                   0.312                   0.315
# 308                    NaN                     NaN                     NaN
#
#      SOIL_MOISTURE_100_DAILY  SOIL_TEMP_5_DAILY  SOIL_TEMP_10_DAILY  \
# 0                        NaN                NaN                 NaN
# 1                        NaN                NaN                 NaN
# 2                        NaN                NaN                 NaN
# 3                        NaN                NaN                 NaN
# 4                        NaN                NaN                 NaN
# ..                       ...                ...                 ...
# 304                    0.021                7.0                 7.7
# 305                    0.021                6.4                 6.9
# 306                    0.019                6.9                 7.0
# 307                    0.024                8.1                 7.9
# 308                      NaN                NaN                 NaN
#
#      SOIL_TEMP_20_DAILY  SOIL_TEMP_50_DAILY  SOIL_TEMP_100_DAILY
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
# ..                  ...                 ...                  ...
# 304                 8.7                10.0                 11.6
# 305                 7.8                 9.3                 11.3
# 306                 7.7                 8.9                 10.9
# 307                 8.3                 8.9                 10.6
# 308                 NaN                 NaN                  NaN
#
# [6949 rows x 28 columns]

# %%
Date = pd.to_datetime(df.LST_DATE, format='%Y%m%d', errors='coerce')
df['Time'] = Date

# %%
df.columns
# Out:
# Index(['WBANNO', 'LST_DATE', 'CRX_VN', 'LONGITUDE', 'LATITUDE', 'T_DAILY_MAX',
#        'T_DAILY_MIN', 'T_DAILY_MEAN', 'T_DAILY_AVG', 'P_DAILY_CALC',
#        'SOLARAD_DAILY', 'SUR_TEMP_DAILY_TYPE', 'SUR_TEMP_DAILY_MAX',
#        'SUR_TEMP_DAILY_MIN', 'SUR_TEMP_DAILY_AVG', 'RH_DAILY_MAX',
#        'RH_DAILY_MIN', 'RH_DAILY_AVG', 'SOIL_MOISTURE_5_DAILY',
#        'SOIL_MOISTURE_10_DAILY', 'SOIL_MOISTURE_20_DAILY',
#        'SOIL_MOISTURE_50_DAILY', 'SOIL_MOISTURE_100_DAILY',
#        'SOIL_TEMP_5_DAILY', 'SOIL_TEMP_10_DAILY', 'SOIL_TEMP_20_DAILY',
#        'SOIL_TEMP_50_DAILY', 'SOIL_TEMP_100_DAILY', 'Time'],
#       dtype='object')

# %%
data = df[['T_DAILY_MAX',
       'T_DAILY_MIN', 'T_DAILY_MEAN', 'T_DAILY_AVG', 'P_DAILY_CALC',
       'SOLARAD_DAILY', 'SUR_TEMP_DAILY_MAX',
       'SUR_TEMP_DAILY_MIN', 'SUR_TEMP_DAILY_AVG', 'RH_DAILY_MAX',
       'RH_DAILY_MIN', 'RH_DAILY_AVG']]

# %%
data.index = df['Time']

# %%
# check for N/A
data.min()
# Out:
# T_DAILY_MAX          -17.90
# T_DAILY_MIN          -30.90
# T_DAILY_MEAN         -24.40
# T_DAILY_AVG          -23.20
# P_DAILY_CALC           0.00
# SOLARAD_DAILY          0.06
# SUR_TEMP_DAILY_MAX   -16.50
# SUR_TEMP_DAILY_MIN   -36.00
# SUR_TEMP_DAILY_AVG   -23.60
# RH_DAILY_MAX          51.50
# RH_DAILY_MIN          11.90
# RH_DAILY_AVG          36.40
# dtype: float64

# %%
data
# Out:
#             T_DAILY_MAX  T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  \
# Time
# 2004-10-27          NaN          NaN           NaN          NaN           NaN
# 2004-10-28         12.7         -0.3           6.2          5.0           0.0
# 2004-10-29         16.3          2.5           9.4          9.7           0.0
# 2004-10-30         17.5         10.5          14.0         14.5           1.8
# 2004-10-31         17.0          9.1          13.1         12.6           0.0
# ...                 ...          ...           ...          ...           ...
# 2023-11-01          3.5         -2.2           0.6          0.2           3.0
# 2023-11-02          6.1         -3.3           1.4          1.0           0.0
# 2023-11-03         12.9          1.4           7.1          7.4           0.0
# 2023-11-04         13.4          5.7           9.6          9.5           0.0
# 2023-11-05          NaN          NaN           NaN          NaN           NaN
#
#             SOLARAD_DAILY  SUR_TEMP_DAILY_MAX  SUR_TEMP_DAILY_MIN  \
# Time
# 2004-10-27            NaN                 NaN                 NaN
# 2004-10-28          12.67                 NaN                 NaN
# 2004-10-29           8.99                 NaN                 NaN
# 2004-10-30           4.14                 NaN                 NaN
# 2004-10-31           3.42                 NaN                 NaN
# ...                   ...                 ...                 ...
# 2023-11-01           5.25                 9.0                -4.6
# 2023-11-02           6.21                12.1                -5.2
# 2023-11-03          10.68                13.5                -1.1
# 2023-11-04           5.49                16.5                 3.5
# 2023-11-05            NaN                 NaN                 NaN
#
#             SUR_TEMP_DAILY_AVG  RH_DAILY_MAX  RH_DAILY_MIN  RH_DAILY_AVG
# Time
# 2004-10-27                 NaN           NaN           NaN           NaN
# 2004-10-28                 6.5           NaN           NaN           NaN
# 2004-10-29                10.2           NaN           NaN           NaN
# 2004-10-30                13.5           NaN           NaN           NaN
# 2004-10-31                10.8           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# 2023-11-01                 0.3          89.9          69.2          83.8
# 2023-11-02                 0.6          90.0          53.4          75.2
# 2023-11-03                 5.7          63.6          26.1          43.0
# 2023-11-04                 8.0          78.3          34.7          50.7
# 2023-11-05                 NaN           NaN           NaN           NaN
#
# [6949 rows x 12 columns]

# %%
data.isna().sum()
# Out:
# T_DAILY_MAX             76
# T_DAILY_MIN             76
# T_DAILY_MEAN            76
# T_DAILY_AVG             77
# P_DAILY_CALC            47
# SOLARAD_DAILY           56
# SUR_TEMP_DAILY_MAX     438
# SUR_TEMP_DAILY_MIN     438
# SUR_TEMP_DAILY_AVG      56
# RH_DAILY_MAX          2405
# RH_DAILY_MIN          2405
# RH_DAILY_AVG          2405
# dtype: int64

# %%
# Check data types
data.dtypes
# Out:
# T_DAILY_MAX           float64
# T_DAILY_MIN           float64
# T_DAILY_MEAN          float64
# T_DAILY_AVG           float64
# P_DAILY_CALC          float64
# SOLARAD_DAILY         float64
# SUR_TEMP_DAILY_MAX    float64
# SUR_TEMP_DAILY_MIN    float64
# SUR_TEMP_DAILY_AVG    float64
# RH_DAILY_MAX          float64
# RH_DAILY_MIN          float64
# RH_DAILY_AVG          float64
# dtype: object

# %%
data.shape
# Out:
# (6949, 12)

# %%
# forward fill the missing values  
data.ffill(axis = 0, inplace = True)

# %%
data
# Out:
#             T_DAILY_MAX  T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  \
# Time
# 2004-10-27          NaN          NaN           NaN          NaN           NaN
# 2004-10-28         12.7         -0.3           6.2          5.0           0.0
# 2004-10-29         16.3          2.5           9.4          9.7           0.0
# 2004-10-30         17.5         10.5          14.0         14.5           1.8
# 2004-10-31         17.0          9.1          13.1         12.6           0.0
# ...                 ...          ...           ...          ...           ...
# 2023-11-01          3.5         -2.2           0.6          0.2           3.0
# 2023-11-02          6.1         -3.3           1.4          1.0           0.0
# 2023-11-03         12.9          1.4           7.1          7.4           0.0
# 2023-11-04         13.4          5.7           9.6          9.5           0.0
# 2023-11-05         13.4          5.7           9.6          9.5           0.0
#
#             SOLARAD_DAILY  SUR_TEMP_DAILY_MAX  SUR_TEMP_DAILY_MIN  \
# Time
# 2004-10-27            NaN                 NaN                 NaN
# 2004-10-28          12.67                 NaN                 NaN
# 2004-10-29           8.99                 NaN                 NaN
# 2004-10-30           4.14                 NaN                 NaN
# 2004-10-31           3.42                 NaN                 NaN
# ...                   ...                 ...                 ...
# 2023-11-01           5.25                 9.0                -4.6
# 2023-11-02           6.21                12.1                -5.2
# 2023-11-03          10.68                13.5                -1.1
# 2023-11-04           5.49                16.5                 3.5
# 2023-11-05           5.49                16.5                 3.5
#
#             SUR_TEMP_DAILY_AVG  RH_DAILY_MAX  RH_DAILY_MIN  RH_DAILY_AVG
# Time
# 2004-10-27                 NaN           NaN           NaN           NaN
# 2004-10-28                 6.5           NaN           NaN           NaN
# 2004-10-29                10.2           NaN           NaN           NaN
# 2004-10-30                13.5           NaN           NaN           NaN
# 2004-10-31                10.8           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# 2023-11-01                 0.3          89.9          69.2          83.8
# 2023-11-02                 0.6          90.0          53.4          75.2
# 2023-11-03                 5.7          63.6          26.1          43.0
# 2023-11-04                 8.0          78.3          34.7          50.7
# 2023-11-05                 8.0          78.3          34.7          50.7
#
# [6949 rows x 12 columns]

# %%
# drop NaN at the top
data.dropna(inplace = True)

# %%
# set target
data['target'] = data['T_DAILY_AVG']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(data)
scaled_data = scaler.transform(data)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(scaled_data, test_size=0.2, shuffle = False)

# %%
train.shape
# Out:
# (3672, 13)

# %%
test.shape
# Out:
# (918, 13)

# %%
# splitting data into sequences
def split_sequences(features, target, seq_len, forecast_len):
    X,y = list(), list()
    for i in range(len(features)):
        end_input = i + seq_len
        end_predict = end_input + forecast_len
        if end_predict > len(features)-1:
            break
        seq_x, seq_y = features[i:end_input,:], target[end_input:end_predict]
        X.append(seq_x)
        y.append(seq_y)
    return tf.convert_to_tensor(X, dtype=tf.float64), tf.convert_to_tensor(y, dtype=tf.float64)

# %%
# input:predict = 4:1
seq_len = 100
forecast_len = 1
X_train, y_train = split_sequences(train[:,:-1], train[:,-1], seq_len = seq_len, forecast_len = forecast_len)
X_test, y_test = split_sequences(test[:,:-1], test[:,-1],seq_len = seq_len, forecast_len =  forecast_len)

# %%
X_train.shape
# Out:
# TensorShape([3571, 100, 12])

# %%
y_train.shape
# Out:
# TensorShape([3571, 1])

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, RNN, LSTMCell, Input
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

model = Sequential([
    LSTM(units=24, activation = 'tanh', input_shape = X_train.shape[1:], return_sequences=True, name = 'lstm_1'),
    LSTM(units=24, activation = 'tanh', input_shape = X_train.shape[1:], return_sequences=False, name = 'lstm_2'),
    Dense(units=forecast_len, activation = None, name = 'dense_1')
    
], name = 'sequential')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100, 24)           3552
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 24)                4704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 8,281
# Trainable params: 8,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate = 0.01))
model.fit(X_train, 
          y_train, 
          batch_size=100,
          epochs=100,
          verbose='auto',
          callbacks=None,
          validation_split=0.2,
          shuffle=True)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 3s 38ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 2/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 3/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 4/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 5/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 6/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 7/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 8/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 9/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 10/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 11/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 12/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 13/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 14/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 15/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 16/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 17/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 18/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 19/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 20/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 21/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 22/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 23/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 24/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 25/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 26/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0047
# Epoch 27/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 28/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 29/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 30/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 31/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 32/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 33/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 34/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 35/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 36/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 37/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0041
# Epoch 38/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 39/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 40/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 41/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 42/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0040
# Epoch 43/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0042
# Epoch 44/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0055
# Epoch 45/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 46/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 47/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 48/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 49/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 50/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 51/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 52/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 53/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0047
# Epoch 54/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 55/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 56/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 57/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0055
# Epoch 58/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 59/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 60/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 61/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 62/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 63/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 64/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0049
# Epoch 65/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0055
# Epoch 66/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 67/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0051
# Epoch 68/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 69/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 70/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 71/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0048
# Epoch 72/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0063
# Epoch 73/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0050
# Epoch 74/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 75/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 76/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 77/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 78/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 79/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0051
# Epoch 80/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 81/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0061
# Epoch 82/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 83/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 0.0056
# Epoch 84/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 0.0057
# Epoch 85/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 86/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 87/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0055
# Epoch 88/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0059
# Epoch 89/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0054
# Epoch 90/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 91/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 92/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 93/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 94/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 95/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 96/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 97/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 98/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 99/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0056
# Epoch 100/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0063

# %%
y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

# %%
plt.plot(y_train[:,0], label = 'real', alpha = 0.5)
plt.plot(y_hat_train[:,0], label = 'predict', alpha = 0.5)
plt.legend()
plt.show()

# %%
plt.plot(y_test[:,0], label = 'real', alpha = 0.5)
plt.plot(y_hat_test[:,0], label = 'predict', alpha = 0.5)
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score

print('r2')
print('train set:', r2_score(y_train, y_hat_train, sample_weight=None))
print('test set:', r2_score(y_test, y_hat_test, sample_weight=None))
# Out:
# r2
# train set: 0.9319736504982732
# test set: 0.8498651152176518
