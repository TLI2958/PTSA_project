# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
# Check for GPU
import tensorflow as tf
try:
    from google.colab import drive
    IN_COLAB=True
except:
    IN_COLAB=False

if IN_COLAB:
    print("We're running Colab")
else:
    print(tf.config.list_physical_devices())
    print('\nCUDA GPU: ' + str(tf.test.is_gpu_available(cuda_only=True)))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING:tensorflow:From C:\Users\Beebe\AppData\Local\Temp\ipykernel_22856\4004085722.py:13: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
#
# CUDA GPU: True

# %% [markdown]
# # Data Preprocessing

# %%
import os
os.chdir('..')

df = pd.read_csv('./daily01-ithaca/daily01-NY_Ithaca_13_E.csv', header = 0, index_col = 0)

# %%
df
# Out:
#      WBANNO  LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0     64758  20041027   1.201     -76.25     42.44          NaN          NaN
# 1     64758  20041028   1.201     -76.25     42.44         12.7         -0.3
# 2     64758  20041029   1.201     -76.25     42.44         16.3          2.5
# 3     64758  20041030   1.201     -76.25     42.44         17.5         10.5
# 4     64758  20041031   1.201     -76.25     42.44         17.0          9.1
# ..      ...       ...     ...        ...       ...          ...          ...
# 304   64758  20231101   2.622     -76.25     42.44          3.5         -2.2
# 305   64758  20231102   2.622     -76.25     42.44          6.1         -3.3
# 306   64758  20231103   2.622     -76.25     42.44         12.9          1.4
# 307   64758  20231104   2.622     -76.25     42.44         13.4          5.7
# 308   64758  20231105   2.622     -76.25     42.44          NaN          NaN
#
#      T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  ...  SOIL_MOISTURE_5_DAILY  \
# 0             NaN          NaN           NaN  ...                    NaN
# 1             6.2          5.0           0.0  ...                    NaN
# 2             9.4          9.7           0.0  ...                    NaN
# 3            14.0         14.5           1.8  ...                    NaN
# 4            13.1         12.6           0.0  ...                    NaN
# ..            ...          ...           ...  ...                    ...
# 304           0.6          0.2           3.0  ...                  0.352
# 305           1.4          1.0           0.0  ...                  0.352
# 306           7.1          7.4           0.0  ...                  0.345
# 307           9.6          9.5           0.0  ...                  0.338
# 308           NaN          NaN           NaN  ...                    NaN
#
#     SOIL_MOISTURE_10_DAILY  SOIL_MOISTURE_20_DAILY  SOIL_MOISTURE_50_DAILY  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
# ..                     ...                     ...                     ...
# 304                  0.328                   0.329                   0.364
# 305                  0.323                   0.325                   0.357
# 306                  0.319                   0.320                   0.327
# 307                  0.313                   0.312                   0.315
# 308                    NaN                     NaN                     NaN
#
#      SOIL_MOISTURE_100_DAILY  SOIL_TEMP_5_DAILY  SOIL_TEMP_10_DAILY  \
# 0                        NaN                NaN                 NaN
# 1                        NaN                NaN                 NaN
# 2                        NaN                NaN                 NaN
# 3                        NaN                NaN                 NaN
# 4                        NaN                NaN                 NaN
# ..                       ...                ...                 ...
# 304                    0.021                7.0                 7.7
# 305                    0.021                6.4                 6.9
# 306                    0.019                6.9                 7.0
# 307                    0.024                8.1                 7.9
# 308                      NaN                NaN                 NaN
#
#      SOIL_TEMP_20_DAILY  SOIL_TEMP_50_DAILY  SOIL_TEMP_100_DAILY
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
# ..                  ...                 ...                  ...
# 304                 8.7                10.0                 11.6
# 305                 7.8                 9.3                 11.3
# 306                 7.7                 8.9                 10.9
# 307                 8.3                 8.9                 10.6
# 308                 NaN                 NaN                  NaN
#
# [6949 rows x 28 columns]

# %%
Date = pd.to_datetime(df.LST_DATE, format='%Y%m%d', errors='coerce')
df['Time'] = Date

# %%
df.columns
# Out:
# Index(['WBANNO', 'LST_DATE', 'CRX_VN', 'LONGITUDE', 'LATITUDE', 'T_DAILY_MAX',
#        'T_DAILY_MIN', 'T_DAILY_MEAN', 'T_DAILY_AVG', 'P_DAILY_CALC',
#        'SOLARAD_DAILY', 'SUR_TEMP_DAILY_TYPE', 'SUR_TEMP_DAILY_MAX',
#        'SUR_TEMP_DAILY_MIN', 'SUR_TEMP_DAILY_AVG', 'RH_DAILY_MAX',
#        'RH_DAILY_MIN', 'RH_DAILY_AVG', 'SOIL_MOISTURE_5_DAILY',
#        'SOIL_MOISTURE_10_DAILY', 'SOIL_MOISTURE_20_DAILY',
#        'SOIL_MOISTURE_50_DAILY', 'SOIL_MOISTURE_100_DAILY',
#        'SOIL_TEMP_5_DAILY', 'SOIL_TEMP_10_DAILY', 'SOIL_TEMP_20_DAILY',
#        'SOIL_TEMP_50_DAILY', 'SOIL_TEMP_100_DAILY', 'Time'],
#       dtype='object')

# %%
data = df[['T_DAILY_MAX',
       'T_DAILY_MIN', 'T_DAILY_MEAN', 'T_DAILY_AVG', 'P_DAILY_CALC',
       'SOLARAD_DAILY', 'SUR_TEMP_DAILY_MAX',
       'SUR_TEMP_DAILY_MIN', 'SUR_TEMP_DAILY_AVG', 'RH_DAILY_MAX',
       'RH_DAILY_MIN', 'RH_DAILY_AVG']]

# %%
data.index = df['Time']

# %%
# check for N/A
data.min()
# Out:
# T_DAILY_MAX          -17.90
# T_DAILY_MIN          -30.90
# T_DAILY_MEAN         -24.40
# T_DAILY_AVG          -23.20
# P_DAILY_CALC           0.00
# SOLARAD_DAILY          0.06
# SUR_TEMP_DAILY_MAX   -16.50
# SUR_TEMP_DAILY_MIN   -36.00
# SUR_TEMP_DAILY_AVG   -23.60
# RH_DAILY_MAX          51.50
# RH_DAILY_MIN          11.90
# RH_DAILY_AVG          36.40
# dtype: float64

# %%
data
# Out:
#             T_DAILY_MAX  T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  \
# Time
# 2004-10-27          NaN          NaN           NaN          NaN           NaN
# 2004-10-28         12.7         -0.3           6.2          5.0           0.0
# 2004-10-29         16.3          2.5           9.4          9.7           0.0
# 2004-10-30         17.5         10.5          14.0         14.5           1.8
# 2004-10-31         17.0          9.1          13.1         12.6           0.0
# ...                 ...          ...           ...          ...           ...
# 2023-11-01          3.5         -2.2           0.6          0.2           3.0
# 2023-11-02          6.1         -3.3           1.4          1.0           0.0
# 2023-11-03         12.9          1.4           7.1          7.4           0.0
# 2023-11-04         13.4          5.7           9.6          9.5           0.0
# 2023-11-05          NaN          NaN           NaN          NaN           NaN
#
#             SOLARAD_DAILY  SUR_TEMP_DAILY_MAX  SUR_TEMP_DAILY_MIN  \
# Time
# 2004-10-27            NaN                 NaN                 NaN
# 2004-10-28          12.67                 NaN                 NaN
# 2004-10-29           8.99                 NaN                 NaN
# 2004-10-30           4.14                 NaN                 NaN
# 2004-10-31           3.42                 NaN                 NaN
# ...                   ...                 ...                 ...
# 2023-11-01           5.25                 9.0                -4.6
# 2023-11-02           6.21                12.1                -5.2
# 2023-11-03          10.68                13.5                -1.1
# 2023-11-04           5.49                16.5                 3.5
# 2023-11-05            NaN                 NaN                 NaN
#
#             SUR_TEMP_DAILY_AVG  RH_DAILY_MAX  RH_DAILY_MIN  RH_DAILY_AVG
# Time
# 2004-10-27                 NaN           NaN           NaN           NaN
# 2004-10-28                 6.5           NaN           NaN           NaN
# 2004-10-29                10.2           NaN           NaN           NaN
# 2004-10-30                13.5           NaN           NaN           NaN
# 2004-10-31                10.8           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# 2023-11-01                 0.3          89.9          69.2          83.8
# 2023-11-02                 0.6          90.0          53.4          75.2
# 2023-11-03                 5.7          63.6          26.1          43.0
# 2023-11-04                 8.0          78.3          34.7          50.7
# 2023-11-05                 NaN           NaN           NaN           NaN
#
# [6949 rows x 12 columns]

# %%
data.isna().sum()
# Out:
# T_DAILY_MAX             76
# T_DAILY_MIN             76
# T_DAILY_MEAN            76
# T_DAILY_AVG             77
# P_DAILY_CALC            47
# SOLARAD_DAILY           56
# SUR_TEMP_DAILY_MAX     438
# SUR_TEMP_DAILY_MIN     438
# SUR_TEMP_DAILY_AVG      56
# RH_DAILY_MAX          2405
# RH_DAILY_MIN          2405
# RH_DAILY_AVG          2405
# dtype: int64

# %%
# Check data types
data.dtypes
# Out:
# T_DAILY_MAX           float64
# T_DAILY_MIN           float64
# T_DAILY_MEAN          float64
# T_DAILY_AVG           float64
# P_DAILY_CALC          float64
# SOLARAD_DAILY         float64
# SUR_TEMP_DAILY_MAX    float64
# SUR_TEMP_DAILY_MIN    float64
# SUR_TEMP_DAILY_AVG    float64
# RH_DAILY_MAX          float64
# RH_DAILY_MIN          float64
# RH_DAILY_AVG          float64
# dtype: object

# %%
data.shape
# Out:
# (6949, 12)

# %%
# forward fill the missing values  
data.ffill(axis = 0, inplace = True)

# %%
data
# Out:
#             T_DAILY_MAX  T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  \
# Time
# 2004-10-27          NaN          NaN           NaN          NaN           NaN
# 2004-10-28         12.7         -0.3           6.2          5.0           0.0
# 2004-10-29         16.3          2.5           9.4          9.7           0.0
# 2004-10-30         17.5         10.5          14.0         14.5           1.8
# 2004-10-31         17.0          9.1          13.1         12.6           0.0
# ...                 ...          ...           ...          ...           ...
# 2023-11-01          3.5         -2.2           0.6          0.2           3.0
# 2023-11-02          6.1         -3.3           1.4          1.0           0.0
# 2023-11-03         12.9          1.4           7.1          7.4           0.0
# 2023-11-04         13.4          5.7           9.6          9.5           0.0
# 2023-11-05         13.4          5.7           9.6          9.5           0.0
#
#             SOLARAD_DAILY  SUR_TEMP_DAILY_MAX  SUR_TEMP_DAILY_MIN  \
# Time
# 2004-10-27            NaN                 NaN                 NaN
# 2004-10-28          12.67                 NaN                 NaN
# 2004-10-29           8.99                 NaN                 NaN
# 2004-10-30           4.14                 NaN                 NaN
# 2004-10-31           3.42                 NaN                 NaN
# ...                   ...                 ...                 ...
# 2023-11-01           5.25                 9.0                -4.6
# 2023-11-02           6.21                12.1                -5.2
# 2023-11-03          10.68                13.5                -1.1
# 2023-11-04           5.49                16.5                 3.5
# 2023-11-05           5.49                16.5                 3.5
#
#             SUR_TEMP_DAILY_AVG  RH_DAILY_MAX  RH_DAILY_MIN  RH_DAILY_AVG
# Time
# 2004-10-27                 NaN           NaN           NaN           NaN
# 2004-10-28                 6.5           NaN           NaN           NaN
# 2004-10-29                10.2           NaN           NaN           NaN
# 2004-10-30                13.5           NaN           NaN           NaN
# 2004-10-31                10.8           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# 2023-11-01                 0.3          89.9          69.2          83.8
# 2023-11-02                 0.6          90.0          53.4          75.2
# 2023-11-03                 5.7          63.6          26.1          43.0
# 2023-11-04                 8.0          78.3          34.7          50.7
# 2023-11-05                 8.0          78.3          34.7          50.7
#
# [6949 rows x 12 columns]

# %%
# drop NaN at the top
data.dropna(inplace = True)

# %%
# set target
data['target'] = data['T_DAILY_AVG']

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2, shuffle = False)

# %%
from sklearn.preprocessing import MinMaxScaler
import pickle

scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

with open('./LSTM/models_daily_v2/daily_v2_scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
train.shape
# Out:
# (3672, 13)

# %%
test.shape
# Out:
# (918, 13)

# %%
# splitting data into sequences
def split_sequences(features, target, seq_len, forecast_len):
    X,y = list(), list()
    for i in range(len(features)):
        end_input = i + seq_len
        end_predict = end_input + forecast_len
        if end_predict > len(features)-1:
            break
        seq_x, seq_y = features[i:end_input,:], target[end_input:end_predict]
        X.append(seq_x)
        y.append(seq_y)
    return tf.convert_to_tensor(X, dtype=tf.float64), tf.convert_to_tensor(y, dtype=tf.float64)

# %% [markdown]
# # Define Model

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, RNN, LSTMCell, Input, Bidirectional
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

class MyModel(tf.keras.Model):

    def __init__(self, input_shape, output_shape, name = 'LSTM-FC'):
        super().__init__(name = name)
        self.input_layer = Input(shape = input_shape, name = 'input')
        self.lstm1 = LSTM(units=30, activation = 'tanh', input_shape = input_shape, return_sequences=False, name = 'lstm_1')
        self.dense1 = Dense(units=20, activation = 'relu', name = 'dense_1')
        self.dense2 = Dense(units=10, activation = 'relu', name = 'dense_2')
        self.dense3 = Dense(units = output_shape, activation = None, name = 'dense_3')
        #self.dropout = tf.keras.layers.Dropout(0.5)

    def call(self, inputs, training=False):
        x = self.lstm1(inputs)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        #if training:
        #  x = self.dropout(x, training=training)
        return x
    
    def summary(self):
        model = Model(inputs = [self.input_layer], outputs = self.call(self.input_layer), name = self.name)
        return model.summary()

# %% [markdown]
# # Model Training
# ## input length : output length = 16:4

# %%
# prepare sequences
seq_len = 16
forecast_len = 4
X_train, y_train = split_sequences(train[:,:-1], train[:,-1], seq_len = seq_len, forecast_len = forecast_len)
X_test, y_test = split_sequences(test[:,:-1], test[:,-1],seq_len = seq_len, forecast_len =  forecast_len)
n_features = X_train.shape[2]

# %%
X_train.shape
# Out:
# TensorShape([3652, 16, 12])

# %%
y_train.shape
# Out:
# TensorShape([3652, 4])

# %%
# create model instance
model_name = 'LSTM-FC_16-4'
model = MyModel(input_shape = (seq_len, n_features), output_shape = (forecast_len), name = model_name)
model.summary()
# Out:
# Model: "LSTM-FC_16-4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 16, 12)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30)                5160
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 44
# =================================================================
# Total params: 6,034
# Trainable params: 6,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate = 0.01), metrics = ['mse', 'acc'])
model.fit(X_train, 
          y_train, 
          batch_size=100,
          epochs=30,
          verbose='auto',
          callbacks=None,
          validation_split=0.1,
          shuffle=True)

# save trained model
model.save('./LSTM/models_daily_v2/' + model_name)
# Out:
# Epoch 1/30
# 33/33 [==============================] - 6s 22ms/step - loss: 0.1434 - mse: 0.1434 - acc: 0.2255 - val_loss: 0.0167 - val_mse: 0.0167 - val_acc: 0.2869
# Epoch 2/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0107 - mse: 0.0107 - acc: 0.2270 - val_loss: 0.0082 - val_mse: 0.0082 - val_acc: 0.2787
# Epoch 3/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.2377 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.2240
# Epoch 4/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.2352 - val_loss: 0.0081 - val_mse: 0.0081 - val_acc: 0.2459
# Epoch 5/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.2285 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.2131
# Epoch 6/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0079 - mse: 0.0079 - acc: 0.2383 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.2459
# Epoch 7/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0079 - mse: 0.0079 - acc: 0.2358 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.2814
# Epoch 8/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2489 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.2077
# Epoch 9/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2495 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.2842
# Epoch 10/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - acc: 0.2638 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.2514
# Epoch 11/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0079 - mse: 0.0079 - acc: 0.2772 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.3060
# Epoch 12/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0075 - mse: 0.0075 - acc: 0.2982 - val_loss: 0.0071 - val_mse: 0.0071 - val_acc: 0.2896
# Epoch 13/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0075 - mse: 0.0075 - acc: 0.3189 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.3388
# Epoch 14/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0074 - mse: 0.0074 - acc: 0.3284 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.3060
# Epoch 15/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0074 - mse: 0.0074 - acc: 0.3180 - val_loss: 0.0066 - val_mse: 0.0066 - val_acc: 0.3798
# Epoch 16/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0073 - mse: 0.0073 - acc: 0.3463 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.3115
# Epoch 17/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0072 - mse: 0.0072 - acc: 0.3372 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.4235
# Epoch 18/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0072 - mse: 0.0072 - acc: 0.3536 - val_loss: 0.0066 - val_mse: 0.0066 - val_acc: 0.4208
# Epoch 19/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0073 - mse: 0.0073 - acc: 0.3533 - val_loss: 0.0066 - val_mse: 0.0066 - val_acc: 0.3497
# Epoch 20/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3704 - val_loss: 0.0066 - val_mse: 0.0066 - val_acc: 0.4180
# Epoch 21/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3679 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.3825
# Epoch 22/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0071 - mse: 0.0071 - acc: 0.3682 - val_loss: 0.0065 - val_mse: 0.0065 - val_acc: 0.3661
# Epoch 23/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0075 - mse: 0.0075 - acc: 0.3594 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.3005
# Epoch 24/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3868 - val_loss: 0.0066 - val_mse: 0.0066 - val_acc: 0.3115
# Epoch 25/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3649 - val_loss: 0.0067 - val_mse: 0.0067 - val_acc: 0.3443
# Epoch 26/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3576 - val_loss: 0.0067 - val_mse: 0.0067 - val_acc: 0.4153
# Epoch 27/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3685 - val_loss: 0.0067 - val_mse: 0.0067 - val_acc: 0.4044
# Epoch 28/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0071 - mse: 0.0071 - acc: 0.3609 - val_loss: 0.0065 - val_mse: 0.0065 - val_acc: 0.3306
# Epoch 29/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3865 - val_loss: 0.0067 - val_mse: 0.0067 - val_acc: 0.3880
# Epoch 30/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - acc: 0.3865 - val_loss: 0.0065 - val_mse: 0.0065 - val_acc: 0.3907
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_16-4\assets
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_16-4\assets

# %%
y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('mean_squared_error')
print('train set:', mean_squared_error(y_train, y_hat_train, sample_weight=None))
print('test set:', mean_squared_error(y_test, y_hat_test, sample_weight=None))
# Out:
# mean_squared_error
# train set: 0.006819459963292694
# test set: 0.006730547450247808

# %% [markdown]
# ## input length : output length = 24:6

# %%
# reset memory
tf.Graph().as_default() 

# prepare sequences
seq_len = 24
forecast_len = 6
X_train, y_train = split_sequences(train[:,:-1], train[:,-1], seq_len = seq_len, forecast_len = forecast_len)
X_test, y_test = split_sequences(test[:,:-1], test[:,-1],seq_len = seq_len, forecast_len =  forecast_len)
n_features = X_train.shape[2]

# %%
# create model instance
model_name = 'LSTM-FC_24-6'
model = MyModel(input_shape = (seq_len, n_features), output_shape = (forecast_len), name = model_name)
model.summary()
# Out:
# Model: "LSTM-FC_24-6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 24, 12)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30)                5160
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 66
# =================================================================
# Total params: 6,056
# Trainable params: 6,056
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate = 0.01), metrics = ['mse', 'acc'])
model.fit(X_train, 
          y_train, 
          batch_size=100,
          epochs=30,
          verbose='auto',
          callbacks=None,
          validation_split=0.1,
          shuffle=True)

# save trained model
model.save('./LSTM/models_daily_v2/' + model_name)
# Out:
# Epoch 1/30
# 33/33 [==============================] - 3s 22ms/step - loss: 0.0321 - mse: 0.0321 - acc: 0.1550 - val_loss: 0.0083 - val_mse: 0.0083 - val_acc: 0.2219
# Epoch 2/30
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - acc: 0.1684 - val_loss: 0.0082 - val_mse: 0.0082 - val_acc: 0.1890
# Epoch 3/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - acc: 0.1825 - val_loss: 0.0079 - val_mse: 0.0079 - val_acc: 0.2027
# Epoch 4/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0085 - mse: 0.0085 - acc: 0.1858 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.2137
# Epoch 5/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1794 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.2219
# Epoch 6/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1941 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.2548
# Epoch 7/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.2093 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1890
# Epoch 8/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.2130 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.2274
# Epoch 9/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.2173 - val_loss: 0.0085 - val_mse: 0.0085 - val_acc: 0.2164
# Epoch 10/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.2090 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.2027
# Epoch 11/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.2270 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.2493
# Epoch 12/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0079 - mse: 0.0079 - acc: 0.2527 - val_loss: 0.0073 - val_mse: 0.0073 - val_acc: 0.2630
# Epoch 13/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.2518 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.2795
# Epoch 14/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.2569 - val_loss: 0.0071 - val_mse: 0.0071 - val_acc: 0.3041
# Epoch 15/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.2484 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.2795
# Epoch 16/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0078 - mse: 0.0078 - acc: 0.2560 - val_loss: 0.0071 - val_mse: 0.0071 - val_acc: 0.2603
# Epoch 17/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - acc: 0.2533 - val_loss: 0.0073 - val_mse: 0.0073 - val_acc: 0.2356
# Epoch 18/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - acc: 0.2511 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.2466
# Epoch 19/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.2563 - val_loss: 0.0071 - val_mse: 0.0071 - val_acc: 0.2904
# Epoch 20/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.2453 - val_loss: 0.0081 - val_mse: 0.0081 - val_acc: 0.1973
# Epoch 21/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.2435 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.3370
# Epoch 22/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2603 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.1753
# Epoch 23/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0079 - mse: 0.0079 - acc: 0.2554 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.3041
# Epoch 24/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2756 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.1918
# Epoch 25/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2438 - val_loss: 0.0073 - val_mse: 0.0073 - val_acc: 0.2438
# Epoch 26/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2524 - val_loss: 0.0068 - val_mse: 0.0068 - val_acc: 0.2274
# Epoch 27/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0075 - mse: 0.0075 - acc: 0.2524 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.3205
# Epoch 28/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0075 - mse: 0.0075 - acc: 0.2557 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.2329
# Epoch 29/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0076 - mse: 0.0076 - acc: 0.2505 - val_loss: 0.0070 - val_mse: 0.0070 - val_acc: 0.2493
# Epoch 30/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - acc: 0.2499 - val_loss: 0.0072 - val_mse: 0.0072 - val_acc: 0.2959
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_24-6\assets
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_24-6\assets

# %%
# evaluate the model
from sklearn.metrics import mean_squared_error

y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

print('mean_squared_error')
print('train set:', mean_squared_error(y_train, y_hat_train, sample_weight=None))
print('test set:', mean_squared_error(y_test, y_hat_test, sample_weight=None))
# Out:
# mean_squared_error
# train set: 0.00755312900193088
# test set: 0.0073587745421180165

# %% [markdown]
# ## input length : output length = 32:8

# %%
# reset memory
tf.Graph().as_default() 

# prepare sequences
seq_len = 32
forecast_len = 8
X_train, y_train = split_sequences(train[:,:-1], train[:,-1], seq_len = seq_len, forecast_len = forecast_len)
X_test, y_test = split_sequences(test[:,:-1], test[:,-1],seq_len = seq_len, forecast_len =  forecast_len)
n_features = X_train.shape[2]

# %%
# create model instance
model_name = 'LSTM-FC_32-8'
model = MyModel(input_shape = (seq_len, n_features), output_shape = (forecast_len), name = model_name)
model.summary()
# Out:
# Model: "LSTM-FC_32-8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 32, 12)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30)                5160
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 88
# =================================================================
# Total params: 6,078
# Trainable params: 6,078
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate = 0.01), metrics = ['mse', 'acc'])
model.fit(X_train, 
          y_train, 
          batch_size=100,
          epochs=30,
          verbose='auto',
          callbacks=None,
          validation_split=0.1,
          shuffle=True)

# save trained model
model.save('./LSTM/models_daily_v2/' + model_name)
# Out:
# Epoch 1/30
# 33/33 [==============================] - 3s 24ms/step - loss: 0.1042 - mse: 0.1042 - acc: 0.1304 - val_loss: 0.0140 - val_mse: 0.0140 - val_acc: 0.1071
# Epoch 2/30
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0109 - mse: 0.0109 - acc: 0.1160 - val_loss: 0.0097 - val_mse: 0.0097 - val_acc: 0.1071
# Epoch 3/30
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0097 - mse: 0.0097 - acc: 0.1221 - val_loss: 0.0090 - val_mse: 0.0090 - val_acc: 0.1401
# Epoch 4/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0098 - mse: 0.0098 - acc: 0.1273 - val_loss: 0.0085 - val_mse: 0.0085 - val_acc: 0.1319
# Epoch 5/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0090 - mse: 0.0090 - acc: 0.1307 - val_loss: 0.0083 - val_mse: 0.0083 - val_acc: 0.1291
# Epoch 6/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - acc: 0.1157 - val_loss: 0.0090 - val_mse: 0.0090 - val_acc: 0.1319
# Epoch 7/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - acc: 0.1261 - val_loss: 0.0084 - val_mse: 0.0084 - val_acc: 0.1346
# Epoch 8/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0085 - mse: 0.0085 - acc: 0.1239 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.1456
# Epoch 9/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0086 - mse: 0.0086 - acc: 0.1255 - val_loss: 0.0081 - val_mse: 0.0081 - val_acc: 0.1126
# Epoch 10/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1221 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1071
# Epoch 11/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1310 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.1319
# Epoch 12/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1331 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.1676
# Epoch 13/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0085 - mse: 0.0085 - acc: 0.1346 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1044
# Epoch 14/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1337 - val_loss: 0.0088 - val_mse: 0.0088 - val_acc: 0.1511
# Epoch 15/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1374 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1236
# Epoch 16/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1328 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1566
# Epoch 17/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1371 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1209
# Epoch 18/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1337 - val_loss: 0.0079 - val_mse: 0.0079 - val_acc: 0.0989
# Epoch 19/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1368 - val_loss: 0.0086 - val_mse: 0.0086 - val_acc: 0.1703
# Epoch 20/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1294 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1291
# Epoch 21/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1325 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1621
# Epoch 22/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1267 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1154
# Epoch 23/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1398 - val_loss: 0.0081 - val_mse: 0.0081 - val_acc: 0.0962
# Epoch 24/30
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.1340 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.1593
# Epoch 25/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1359 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1264
# Epoch 26/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.1300 - val_loss: 0.0079 - val_mse: 0.0079 - val_acc: 0.1126
# Epoch 27/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1392 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1291
# Epoch 28/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1325 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1621
# Epoch 29/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1398 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1841
# Epoch 30/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1411 - val_loss: 0.0081 - val_mse: 0.0081 - val_acc: 0.0879
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_32-8\assets
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_32-8\assets

# %%
# evaluate the model
from sklearn.metrics import mean_squared_error

y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

print('mean_squared_error')
print('train set:', mean_squared_error(y_train, y_hat_train, sample_weight=None))
print('test set:', mean_squared_error(y_test, y_hat_test, sample_weight=None))
# Out:
# mean_squared_error
# train set: 0.008169509256797243
# test set: 0.008158481069716755

# %% [markdown]
# ## input length : output length = 40:10

# %%
# reset memory
tf.Graph().as_default() 

# prepare sequences
seq_len = 40
forecast_len = 10
X_train, y_train = split_sequences(train[:,:-1], train[:,-1], seq_len = seq_len, forecast_len = forecast_len)
X_test, y_test = split_sequences(test[:,:-1], test[:,-1],seq_len = seq_len, forecast_len =  forecast_len)
n_features = X_train.shape[2]

# %%
# create model instance
model_name = 'LSTM-FC_40-10'
model = MyModel(input_shape = (seq_len, n_features), output_shape = (forecast_len), name = model_name)
model.summary()
# Out:
# Model: "LSTM-FC_40-10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 40, 12)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30)                5160
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# =================================================================
# Total params: 6,100
# Trainable params: 6,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate = 0.01), metrics = ['mse', 'acc'])
model.fit(X_train, 
          y_train, 
          batch_size=100,
          epochs=30,
          verbose='auto',
          callbacks=None,
          validation_split=0.1,
          shuffle=True)

# save trained model
model.save('./LSTM/models_daily_v2/' + model_name)
# Out:
# Epoch 1/30
# 33/33 [==============================] - 2s 26ms/step - loss: 0.0528 - mse: 0.0528 - acc: 0.1013 - val_loss: 0.0096 - val_mse: 0.0096 - val_acc: 0.0964
# Epoch 2/30
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0096 - mse: 0.0096 - acc: 0.1157 - val_loss: 0.0091 - val_mse: 0.0091 - val_acc: 0.0937
# Epoch 3/30
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0092 - mse: 0.0092 - acc: 0.1141 - val_loss: 0.0083 - val_mse: 0.0083 - val_acc: 0.1074
# Epoch 4/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0088 - mse: 0.0088 - acc: 0.1206 - val_loss: 0.0086 - val_mse: 0.0086 - val_acc: 0.1543
# Epoch 5/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0090 - mse: 0.0090 - acc: 0.1206 - val_loss: 0.0086 - val_mse: 0.0086 - val_acc: 0.1350
# Epoch 6/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0089 - mse: 0.0089 - acc: 0.1261 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1680
# Epoch 7/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0087 - mse: 0.0087 - acc: 0.1298 - val_loss: 0.0080 - val_mse: 0.0080 - val_acc: 0.1570
# Epoch 8/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0086 - mse: 0.0086 - acc: 0.1353 - val_loss: 0.0077 - val_mse: 0.0077 - val_acc: 0.1488
# Epoch 9/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0086 - mse: 0.0086 - acc: 0.1319 - val_loss: 0.0082 - val_mse: 0.0082 - val_acc: 0.1736
# Epoch 10/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0085 - mse: 0.0085 - acc: 0.1442 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1736
# Epoch 11/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0084 - mse: 0.0084 - acc: 0.1479 - val_loss: 0.0079 - val_mse: 0.0079 - val_acc: 0.1818
# Epoch 12/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0085 - mse: 0.0085 - acc: 0.1519 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1791
# Epoch 13/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1445 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1763
# Epoch 14/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1458 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1791
# Epoch 15/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1602 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1598
# Epoch 16/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1614 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.1901
# Epoch 17/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1574 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1653
# Epoch 18/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1632 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1736
# Epoch 19/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1586 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.1956
# Epoch 20/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.1623 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1708
# Epoch 21/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1737 - val_loss: 0.0076 - val_mse: 0.0076 - val_acc: 0.1956
# Epoch 22/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.1639 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1653
# Epoch 23/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0083 - mse: 0.0083 - acc: 0.1681 - val_loss: 0.0079 - val_mse: 0.0079 - val_acc: 0.1625
# Epoch 24/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0081 - mse: 0.0081 - acc: 0.1620 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.1653
# Epoch 25/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1709 - val_loss: 0.0078 - val_mse: 0.0078 - val_acc: 0.1901
# Epoch 26/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1663 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.2121
# Epoch 27/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0078 - mse: 0.0078 - acc: 0.1752 - val_loss: 0.0075 - val_mse: 0.0075 - val_acc: 0.1708
# Epoch 28/30
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0082 - mse: 0.0082 - acc: 0.1724 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.1846
# Epoch 29/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0080 - mse: 0.0080 - acc: 0.1697 - val_loss: 0.0074 - val_mse: 0.0074 - val_acc: 0.1680
# Epoch 30/30
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0078 - mse: 0.0078 - acc: 0.1712 - val_loss: 0.0073 - val_mse: 0.0073 - val_acc: 0.1708
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_40-10\assets
# INFO:tensorflow:Assets written to: ./LSTM/models_daily_v2/LSTM-FC_40-10\assets

# %%
# evaluate the model
from sklearn.metrics import mean_squared_error

y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

print('mean_squared_error')
print('train set:', mean_squared_error(y_train, y_hat_train, sample_weight=None))
print('test set:', mean_squared_error(y_test, y_hat_test, sample_weight=None))
# Out:
# mean_squared_error
# train set: 0.00764985931919338
# test set: 0.0074693488388376415
